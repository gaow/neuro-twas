# %% [markdown]
# ##Global parameter settings

# %%
[global]
##!/bin/sh
# MAKE SURE FUSION.compute_weights.R IS IN YOUR PATH
# FILL IN THESE PATHS
# For mac user, the mac version of GCTA shall be downloaded saperately, the one came with the Fusion package will not work.
parameter: GCTA = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/gcta_1.93.2beta_mac/gcta64"
parameter: PLINK = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/plink_mac_20200616/plink"
parameter: GEMMA = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/GEMMA"

# Required the customized fusion.compute_weight.mod.R script, other wise will not work
parameter: Rscp = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R"
# Path to the input data
parameter: Datarep = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/Testing/Data/"
# ALTERNATIVELY: ENSURE THAT plink, gcta, gemma CAN BE CALLED FROM PATH AND REMOVE --PATH_* FLAGS BELOW

# PATH TO WORKING DIRECTORY
parameter: wd = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/SOS"

# PATH TO OUTPUT DIRECTORY (population-specific subdirs will be made)
parameter: OUT_DIR = "./WEIGHTS"

# ROWS IN THE MATRIX TO ANALYZE (FOR BATCHED RUNS)
parameter: BATCH_START = 1
parameter: BATCH_END = 56


# PATH TO DIRECTORY CONTAINING LDREF DATA (FROM FUSION WEBSITE or https://data.broadinstitute.org/alkesgroup/FUSION/LDREF.tar.bz2)
parameter: LDREF = "/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF"
# THIS IS USED TO RESTRICT INPUT SNPS TO REFERENCE IDS ONLY

# PATH TO GEUVADIS GENE EXPRESSION MATRIX:
parameter: PRE_GEXP = "GD462.hsq_succ.test.txt"
# GEUVADIS DATA WAS DOWNLOADED FROM https://www.ebi.ac.uk/arrayexpress/experiments/E-GEUV-1/files/analysis_results/

# PATH TO PREFIX FOR GEUVADIS GENOTYPES SPLIT BY CHROMOSOME
# SUBSAMPLE THESE TO THE LDREF SNPS FOR EFFICIENCY
parameter: PRE_GENO = "1000G.EUR"
[STEP_1]
bash: expand= "$[ ]"
    cd $[wd]
    NR="$[BATCH_START]_$[BATCH_END]"
    mkdir -p tmp/$NR
    mkdir -p hsq/$NR
    mkdir -p out/$NR
    mkdir $[OUT_DIR]
    mkdir $[wd]/$[PRE_GEXP]_per_gene
    head -1 $[Datarep]$[PRE_GEXP] | awk '{$1=$2=$3=$4=""; print substr($0,4)}' | fmt -1 > PRE_GEXPID
# Out:
# <div class="sos_logging sos_info">INFO: Running <span class="sos_highlight">STEP_1</span>:
# </div>
# --2020-07-20 22:29:36--  https://github.com/cumc/neuro-twas/blob/master/WIP/pipeline_prototype/FUSION.compute_weights.mod.R
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-07-20 22:29:37 ERROR 404: Not Found.
#
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/SOS/FUSION.compute_weights.mod.R
# <div class="sos_logging sos_info">INFO: Workflow STEP (ID=6bc73c80dd188f11) is executed successfully with 1 completed step.
# </div>

# %%
[STEP_2]
bash: expand= "$[ ]"
cd $[wd]
# extract each gene from the data matrixs to a file
    cat $[Datarep]$[PRE_GEXP] | awk -v s=$[BATCH_START] -v e=$[BATCH_END] 'NR > s && NR <= e' |  while read PARAM; do
    GNAME=`echo $PARAM | awk '{ print $1 }'`
    echo $PARAM > $[wd]/$[PRE_GEXP]_per_gene/$[PRE_GEXP]_$GNAME.txt
    
done

# %%
[STEP_3]
depends: sos_step('STEP_2')
input: f'{wd}/{PRE_GEXP}_per_gene/',group_by=1
bash:expand= "$[ ]"
cd $[wd]
cat $[_input]/* |  while read PARAM; do
# Get the gene positions +/- 500kb
CHR=`echo $PARAM | awk '{ print $3 }'`
P0=`echo $PARAM | awk '{ print $4 - 0.5e6 }'`
P1=`echo $PARAM | awk '{ print $4 + 0.5e6 }'`
GNAME=`echo $PARAM | awk '{ print $1 }'`

OUT="tmp/$[PRE_GEXP].$GNAME"
echo $GNAME $CHR $P0 $P1 $OUT $tmpdir$OUT

## Pull out the current gene expression phenotype, adding patient ID to the expression profile (Note 1 )
echo $PARAM | tr ' ' '\n' | tail -n+5 | paste PRE_GEXPID PRE_GEXPID - > $OUT.pheno
## Get the locus genotypes for all samples and set current gene expression as the phenotype
$[PLINK] --bfile $[LDREF]/$[PRE_GENO].$CHR \
--pheno $OUT.pheno \
--make-bed \
--out $OUT \
--chr $CHR \
--from-bp $P0 \
--to-bp $P1 \
--extract $[LDREF]/$[PRE_GENO].$CHR.bim \
--keep $OUT.pheno \
--allow-no-sex
## Process all samples together (for reference purposes only since this is mult-ethnic data)
mkdir $[OUT_DIR]/ALL
FINAL_OUT="$[OUT_DIR]/ALL/ALL.$GNAME"
#echo $FINAL_OUT
#
#echo $OUT.tmp
echo $[Rscp]
#
Rscript $[Rscp] \
--bfile $OUT \
--tmp $OUT.tmp \
--out $FINAL_OUT \
--verbose 0 \
--save_hsq \
--PATH_gcta $[GCTA] \
--PATH_gemma $[GEMMA] \
--models blup,lasso,top1,enet

#
## Append heritability output to hsq file
cat $FINAL_OUT.hsq >> hsq/hsq
#
## Clean-up just in case
rm -f $FINAL_OUT.hsq $OUT.tmp.*
#
# Remove all intermediate files
echo "end of circle"

done

# %%
%sosrun
# Out:
# WARNING: Embedding script "cd $[wd]..." without indentation is error-prone and will be deprecated in the future.
# WARNING: Embedding script "cd $[wd]..." without indentation is error-prone and will be deprecated in the future.
# <div class="sos_logging sos_info">INFO: Running <span class="sos_highlight">STEP_1</span>:
# </div>
# mkdir: ./WEIGHTS: File exists
# mkdir: /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/SOS/GD462.hsq_succ.test.txt_per_gene: File exists
# end step 1
# <div class="sos_logging sos_info">INFO: Running <span class="sos_highlight">STEP_2</span>:
# </div>
# <div class="sos_logging sos_info">INFO: Running <span class="sos_highlight">STEP_3</span>:
# </div>
# ENSG00000049247.8 1 7413572 8413572 tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8 tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.1
#   --chr 1
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.1.bim
#   --from-bp 7413572
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.pheno
#   --to-bp 8413572
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 451 out of 98642 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.nosex .
# 344 phenotype values present after --pheno.
# --extract: 451 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 451 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000049247.8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000056972.13 6 111427481 112427481 tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13 tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6
#   --chr 6
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6.bim
#   --from-bp 111427481
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.pheno
#   --to-bp 112427481
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 438 out of 75358 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.nosex .
# 344 phenotype values present after --pheno.
# --extract: 438 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 438 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000056972.13.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000095739.6 10 28466271 29466271 tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6 tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.10
#   --chr 10
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.10.bim
#   --from-bp 28466271
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.pheno
#   --to-bp 29466271
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 614 out of 64067 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.nosex .
# 344 phenotype values present after --pheno.
# --extract: 614 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 614 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000095739.6.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000096696.8 6 7041808 8041808 tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8 tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6
#   --chr 6
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6.bim
#   --from-bp 7041808
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.pheno
#   --to-bp 8041808
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 584 out of 75358 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.nosex .
# 344 phenotype values present after --pheno.
# --extract: 584 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 584 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000096696.8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000099998.12 22 24141110 25141110 tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12 tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.22
#   --chr 22
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.22.bim
#   --from-bp 24141110
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.pheno
#   --to-bp 25141110
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 358 out of 17489 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.nosex .
# 344 phenotype values present after --pheno.
# --extract: 358 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 358 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000099998.12.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000106100.6 7 30018400 31018400 tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6 tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.7
#   --chr 7
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.7.bim
#   --from-bp 30018400
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.pheno
#   --to-bp 31018400
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 445 out of 66171 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.nosex .
# 344 phenotype values present after --pheno.
# --extract: 445 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 445 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000106100.6.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000108448.13 17 18101311 19101311 tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13 tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.17
#   --chr 17
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.17.bim
#   --from-bp 18101311
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.pheno
#   --to-bp 19101311
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 219 out of 32218 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.nosex .
# 344 phenotype values present after --pheno.
# --extract: 219 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 219 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000108448.13.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000108797.6 17 40334632 41334632 tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6 tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.17
#   --chr 17
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.17.bim
#   --from-bp 40334632
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.pheno
#   --to-bp 41334632
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 270 out of 32218 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.nosex .
# 344 phenotype values present after --pheno.
# --extract: 270 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 270 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000108797.6.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000115350.7 2 74685619 75685619 tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7 tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2
#   --chr 2
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2.bim
#   --from-bp 74685619
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.pheno
#   --to-bp 75685619
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 472 out of 99735 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.nosex .
# 344 phenotype values present after --pheno.
# --extract: 472 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 472 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000115350.7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000117480.10 1 46359937 47359937 tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10 tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.1
#   --chr 1
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.1.bim
#   --from-bp 46359937
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.pheno
#   --to-bp 47359937
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 364 out of 98642 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.nosex .
# 344 phenotype values present after --pheno.
# --extract: 364 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 364 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000117480.10.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000124374.8 2 70954213 71954213 tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8 tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2
#   --chr 2
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2.bim
#   --from-bp 70954213
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.pheno
#   --to-bp 71954213
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 499 out of 99735 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.nosex .
# 344 phenotype values present after --pheno.
# --extract: 499 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 499 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000124374.8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000124532.9 6 23903153 24903153 tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9 tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6
#   --chr 6
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6.bim
#   --from-bp 23903153
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.pheno
#   --to-bp 24903153
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 626 out of 75358 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.nosex .
# 344 phenotype values present after --pheno.
# --extract: 626 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 626 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000124532.9.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000128886.7 15 43569741 44569741 tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7 tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.15
#   --chr 15
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.15.bim
#   --from-bp 43569741
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.pheno
#   --to-bp 44569741
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 245 out of 35839 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.nosex .
# 344 phenotype values present after --pheno.
# --extract: 245 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 245 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000128886.7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000130544.6 19 6569471 7569471 tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6 tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.19
#   --chr 19
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.19.bim
#   --from-bp 6569471
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.pheno
#   --to-bp 7569471
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 438 out of 22509 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.nosex .
# 344 phenotype values present after --pheno.
# --extract: 438 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 438 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# tmp/GD462.hsq_succ.test.txt.ENSG00000130544.6.tmp.cv.LASSO.lasso  LASSO output did not exist
# end of circle
# ENSG00000135046.9 9 75266673 76266673 tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9 tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.9
#   --chr 9
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.9.bim
#   --from-bp 75266673
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.pheno
#   --to-bp 76266673
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 411 out of 55464 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.nosex .
# 344 phenotype values present after --pheno.
# --extract: 411 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 411 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000135046.9.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000135898.5 2 231325781 232325781 tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5 tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2
#   --chr 2
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2.bim
#   --from-bp 231325781
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.pheno
#   --to-bp 232325781
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 460 out of 99735 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.nosex .
# 344 phenotype values present after --pheno.
# --extract: 460 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 460 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000135898.5.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000136237.12 7 21896763 22896763 tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12 tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.7
#   --chr 7
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.7.bim
#   --from-bp 21896763
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.pheno
#   --to-bp 22896763
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 673 out of 66171 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.nosex .
# 344 phenotype values present after --pheno.
# --extract: 673 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 673 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000136237.12.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000145365.8 4 112707059 113707059 tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8 tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.4
#   --chr 4
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.4.bim
#   --from-bp 112707059
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.pheno
#   --to-bp 113707059
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 404 out of 74924 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.nosex .
# 344 phenotype values present after --pheno.
# --extract: 404 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 404 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000145365.8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000148377.5 10 571799 1571799 tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5 tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.10
#   --chr 10
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.10.bim
#   --from-bp 571799
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.pheno
#   --to-bp 1571799
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 511 out of 64067 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.nosex .
# 344 phenotype values present after --pheno.
# --extract: 511 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 511 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000148377.5.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000151470.7 4 129514472 130514472 tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7 tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.4
#   --chr 4
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.4.bim
#   --from-bp 129514472
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.pheno
#   --to-bp 130514472
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 376 out of 74924 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.nosex .
# 344 phenotype values present after --pheno.
# --extract: 376 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 376 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000151470.7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000155729.8 2 200884507 201884507 tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8 tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2
#   --chr 2
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.2.bim
#   --from-bp 200884507
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.pheno
#   --to-bp 201884507
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 494 out of 99735 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.nosex .
# 344 phenotype values present after --pheno.
# --extract: 494 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 494 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000155729.8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000156218.8 15 83822838 84822838 tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8 tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.15
#   --chr 15
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.15.bim
#   --from-bp 83822838
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8.pheno
#   --to-bp 84822838
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 337 out of 35839 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8.nosex .
# 344 phenotype values present after --pheno.
# --extract: 337 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 337 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000156218.8.bed +
# ...
# 531 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000240583.5.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000240583.5.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000240583.5.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000245648.1 12 10016368 11016368 tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1 tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.12
#   --chr 12
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.12.bim
#   --from-bp 10016368
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.pheno
#   --to-bp 11016368
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 517 out of 58543 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.nosex .
# 344 phenotype values present after --pheno.
# --extract: 517 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 517 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000245648.1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000248049.2 4 68066998 69066998 tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2 tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.4
#   --chr 4
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.4.bim
#   --from-bp 68066998
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.pheno
#   --to-bp 69066998
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 404 out of 74924 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.nosex .
# 344 phenotype values present after --pheno.
# --extract: 404 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 404 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000248049.2.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000250443.2 3 196733857 197733857 tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2 tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.3
#   --chr 3
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.3.bim
#   --from-bp 196733857
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.pheno
#   --to-bp 197733857
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 391 out of 83036 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.nosex .
# 344 phenotype values present after --pheno.
# --extract: 391 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 391 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000250443.2.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000251323.2 11 77640882 78640882 tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2 tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.11
#   --chr 11
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.11.bim
#   --from-bp 77640882
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.pheno
#   --to-bp 78640882
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 402 out of 60977 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.nosex .
# 344 phenotype values present after --pheno.
# --extract: 402 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 402 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000251323.2.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000259382.1 6 31653659 32653659 tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1 tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6
#   --chr 6
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.6.bim
#   --from-bp 31653659
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.pheno
#   --to-bp 32653659
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 171 out of 75358 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.nosex .
# 344 phenotype values present after --pheno.
# --extract: 171 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 171 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000259382.1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000260052.1 16 48171054 49171054 tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1 tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.16
#   --chr 16
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.16.bim
#   --from-bp 48171054
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.pheno
#   --to-bp 49171054
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 352 out of 36526 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.nosex .
# 344 phenotype values present after --pheno.
# --extract: 352 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 352 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000260052.1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# ENSG00000261000.1 1 206177281 207177281 tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1 tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1
# PLINK v1.90b6.18 64-bit (16 Jun 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.1
#   --chr 1
#   --extract /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/LDREF/1000G.EUR.1.bim
#   --from-bp 206177281
#   --keep tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.pheno
#   --make-bed
#   --out tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1
#   --pheno tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.pheno
#   --to-bp 207177281
#
# 16384 MB RAM detected; reserving 8192 MB for main workspace.
# 353 out of 98642 variants loaded from .bim file.
# 489 people (0 males, 0 females, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.nosex .
# 344 phenotype values present after --pheno.
# --extract: 353 variants remaining.
# --keep: 344 people remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 344 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 353 variants and 344 people pass filters and QC.
# Phenotype data is quantitative.
# --make-bed to tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.bed +
# tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.bim +
# tmp/GD462.hsq_succ.test.txt.ENSG00000261000.1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# mkdir: ./WEIGHTS/ALL: File exists
# /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/FUSION.compute_weights.mod.R
# end of circle
# <div class="sos_logging sos_info">INFO: Workflow STEP (ID=bf46bf37c7021b8a) is executed successfully with 3 completed steps.
# </div>

# %%
GD462.hsq_succ.test.txt_per_gene
