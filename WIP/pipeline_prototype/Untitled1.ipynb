# %%
$GEMMA -miss 1 -maf 0 -r2 1 -rpace 1000 -wpace 1000 -bfile $cv_dir/$cv_file -bslmm 2 -o GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.BSLMM
# Out:
# GEMMA 0.97 (2017/12/20) by Xiang Zhou and team (C) 2012-2017
# Reading Files ...
# ## number of total individuals = 275
# ## number of analyzed individuals = 275
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs/var        =      673
# ## number of analyzed SNPs         =      673
# Start Eigen-Decomposition...
# pve estimate =0.132779
# se(pve) =0.0783104
# Calculating UtX...

# %%
/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/GEMMA -miss 1 -maf 0 -r2 1 -rpace 1000 -wpace 1000 -bfile tmp/1_3/GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv -bslmm 2 -o GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.BSLMM -outdir /Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/Testing/out
# Out:
# GEMMA 0.97 (2017/12/20) by Xiang Zhou and team (C) 2012-2017
# Reading Files ...
# ## number of total individuals = 275
# ## number of analyzed individuals = 275
# ## number of covariates = 1
# ## number of phenotypes = 1
# ## number of total SNPs/var        =      673
# ## number of analyzed SNPs         =      673
# Start Eigen-Decomposition...
# pve estimate =0.132779
# se(pve) =0.0783104
# Calculating UtX...

# %%
ls output/
cat output/GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.BSLMM.param.txt
# Out:
# GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.BSLMM.bv.txt
# GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.BSLMM.log.txt
# GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.BSLMM.param.txt
# GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.bv.txt
# GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.log.txt
# GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv.param.txt
# chr	rs	ps	n_miss	alpha	beta	gamma
# 7	rs11770247	21897550	0	-7.396238e-03	0.000000e+00	0.000000e+00
# 7	rs2040664	21897714	0	-6.114057e-03	0.000000e+00	0.000000e+00
# 7	rs11980938	21897871	0	-1.001750e-04	0.000000e+00	0.000000e+00
# 7	rs10245983	21899516	0	-3.933753e-03	0.000000e+00	0.000000e+00
# 7	rs10950880	21900188	0	-2.647688e-03	0.000000e+00	0.000000e+00
# 7	rs12539840	21900213	0	-4.101561e-03	0.000000e+00	0.000000e+00
# 7	rs6976700	21900298	0	7.270982e-03	0.000000e+00	0.000000e+00
# 7	rs4722066	21900924	0	-2.216711e-03	0.000000e+00	0.000000e+00
# ...

# %%
GEMMA="/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/GEMMA"

# %%
cv_dir="/Users/haosun/Documents/WG_Reasearch_Assisstant/Fusion/install/fusion_twas-master/Testing/tmp/1_3"
cv_file="GD462.hsq_succ.test.txt.ENSG00000136237.12.tmp.cv"

# %%
ls
# Out:
# Data					out
# Fusion.compute_weights_testing.ipynb	output
# PRE_GEXPID				pipline_Template.ipynb
# Untitled.ipynb				pipline_for_one-Test.ipynb
# Untitled1.ipynb				plink
# WEIGHTS					plinkexample
# bslmm					test
# fam_ID					tmp
# hsq
